# %% [markdown]
# # Streaming Twitter Data into a MYSQL DATABASE

# %% [markdown]
# - twitter api 발급 과정 좀 상세하게 부탁드리겠습니다~

# %% [markdown]
# - tweeter api 발급
# - mysql 설치
# - tweepy and mysql-connector with python

# %% [markdown]
# # 트위터 키 발급
#
# - [https://developer.twitter.com/en](https://developer.twitter.com/en)
# - [https://developer.twitter.com/en/portal/projects-and-apps](https://developer.twitter.com/en/portal/projects-and-apps)

# %% [markdown]
# # Mysql 설치
# - brew install mysql@5.7
#
# - sudo /usr/local/mysql/support-files/mysql.server start
# - sudo mysql -u root
#
# - brew install mysql-client
# - brew cask install mysqlworkbench
#
# - sudo mysql -u root

# %% [markdown]
# # Twitter API

# %% [markdown]
# - 내 트윗 가져 오기

# %%
# 주의 !pip install tweepy==3.10.0

# %%
consumer_key = "consumer_key"
consumer_secret = 'consumer_secret'

access_token = 'access_token'
access_token_secret = 'access_token_secret'

import tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)
public_tweets = api.home_timeline()
for tweet in public_tweets:
    print(tweet.text)
# Out:
# RT @sungkkshawnpark: 모든 사람이 ‘지름길(shortest path)’만 찾는 것. 맨 처음 신입부터 가장 좋은 기업에서 시작해서, 더 빠르게, 시행착오를 하나도 거치지 않고, 더 높은 연봉으로, 이왕이면 전공할 필요조차 없이. 정말…
# 나는 트위터를 일기장 내지 메모장으로 쓰고 있는데 보는 사람이 많아서 속마음을 다 이야기하지 못하는 것 같다. 부계를 만들어야지.
# RT @Grady_Booch: @default_friend I was born in 1955.
#
# And I still code.
# clojure의 thread macro나 java의 stream 스타일로 RDB를 조회할 수 있다면 좋겠다. sql where가 아니라 filter를 쓰는 방식.
# RT @UnrollHelper: @John_Grib Namaste, you can read it here: https://t.co/Tw1X7lx8Ul Enjoy :) 🤖
# @threadreaderapp unroll
# 멘토가 있으면 좋겠다. 가끔 콱 막힌 느낌이 드는데 그럴 때 조언을 받을 수 있다면...
# 우연한 잡담이 사라지는 것이 가장 아쉽다. https://t.co/qU0MU9gO9O
# RT @tebica: 원격근무의 치명적 단점 5가지 https://t.co/GWDbgW3HUz 내용을 보면 "치명적" 인지는 모르겠는데 단점인것은 많은. 대부분 커뮤니케이션이 어려워졌다는 것. 느낌 전달 어렵고, 잡담 사라짐, 새로운 사람 만알 기회…
# RT @_SiRaH_: 내 주여 그들이 당신의 저주를 극복하기 시작했나이다
# RT @emollick: Successful entrepreneurs are more generous than their investors.
#
# After IPOs, entrepreneurs become philanthropists more quick…
# ...

# %% [markdown]
# # 검색하기

# %% [markdown]
# # Tweetpy 더 써보기

# %%
# main.py 파일 보기 
# https://docs.tweepy.org/ko/v3.10.0/api.html : api 사용법
# https://docs.tweepy.org/ko/v3.10.0/streaming_how_to.html : streaming

# %% [markdown]
# # 키워드 검색하기

# %%
api = tweepy.API(auth)

query = "코로나"
statuses = api.search(q=query, count=100)
for status in statuses:
    print(status.text)
# Out:
# 트친들 당황스러울듯
# 님 4개월 동안 안 나타났잖아요
# 네.. 갓생 살다가 코로나 걸려서 강제로 최고로 나태한 삶을 살고 있으니까요...
# RT @residentWLT: rt 부탁드립니다
# 코로나 확진으로 관극 동선 공유합니다. 미아 커튼콜로 목이 쉰 것 외에는 증상이 없었으나 혹시 몰라 8월 11일부터 매일 키트로 음성 확인 후 외출하였고, 오늘 아침부터 오한이 들어 3시간 간격으로 키…
# RT @sh052512140408: 누가 코로나 별로 안아프다고 했는가🥲 감기랑은 쨉이 안됨. 근육통+발열+기침+두통의 콜라보로 정신을 못차리다가 이제 좀 정신이 듬. 감기의 한 10배정도는 되는 듯😭 다들 코로나 조심하셔요ㅜㅜ
# RT @Estel_Eldalieva: 아미친ㅋㅋㅋ
#
# 3년만에 대면활동 재개에도 '코로나 학번' 경험 없어 발만 동동
# 총학생회, 여름방학 중 '대학문화 전수' 학생자치워크숍 개최
#  https://t.co/uDidu1RXeL
# RT @naanangnaang: 한국이 코로나 방어1위할 땐 사망자 한명씩 나올때마다 기사 쏟아내고 백신맞고 죽은 사람 기사 수백개씩 내더니 발병율 1위 찍는 건 기사가 없음. 지금 코로나 사망자 하루에 70명가까이 나옴.
#
# 딱하나 바뀐 건 정권만…
# RT @yyc1964: 지난 대선은 왜! 패배했습니까?
# 우리 스스로 만든 덫에 빠져
# 세 분 대통령의 가치와
# 문재인정부의 성과들조차
# 계승하지 못해서 패배한 것 아닙니까
#
# 코로나19 성공적 방역, G7 경제, BTS와 기생충 등 문화…
# RT @mbcbf_ever: [출연자 변동 안내]
# 엑스디너리 히어로즈 정수&amp;https://t.co/VsK69cfucb 출연(8월20일 토요일)이 코로나19 여파로 취소되었습니다. 청취자 여러분들의 너른 양해를 구합니다.
#
# #GOT7영재의친한친구 #…
# RT @kjy24k: @ansvmakswlwl @js353 권리당원 참석불가.
# 전국대의원만 참석.
#
# ...

# %%
import pandas as pd
result = [status.text for status in statuses]
data = pd.DataFrame(result)
data.head()

# %% [markdown]
# # 데이터 스트리밍 검색하기

# %%
import tweepy
#override tweepy.StreamListener to add logic to on_status
class MyStreamListener(tweepy.StreamListener):

    def on_status(self, status):
        print(status.text)

# %%
myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

# %%
myStream.filter(track=['python'])
# 비동기 처리 myStream.filter(track=['python'], is_async=True)

# %% [markdown]
# # 다음주에 할 것 mysql 연결 + streaming 데이터 감성 분석
